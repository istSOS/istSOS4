# %%
# %load_ext autoreload
# %autoreload 2

# %%
import istsos4_utils as st
from pprint import pprint

# %%
meteo = st.sta('http://api:5000/istsos4/v1.1/')

# %%
Things = meteo.query_api('Things','$expand=Locations')
# Out:
# INFO:root:query_api request: http://api:5000/istsos4/v1.1/Things?$expand=Locations

# %%
map = meteo.map_things(Things)
# Out:
# INFO:root:query_api request: http://api:5000/istsos4/v1.1/Things?$expand=Locations

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_611771871da37aeb1366f9854d557aed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_611771871da37aeb1366f9854d557aed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_611771871da37aeb1366f9854d557aed = L.map(
#                 &quot;map_611771871da37aeb1366f9854d557aed&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e580c2c2eb40612b356d0f273bf7fada = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e580c2c2eb40612b356d0f273bf7fada.addTo(map_611771871da37aeb1366f9854d557aed);
#
#
#             var marker_8df92f72c3898fe4ac2ffe9ffd48be1e = L.marker(
#                 [48.88763156, 27.800676654],
#                 {}
#             ).addTo(map_611771871da37aeb1366f9854d557aed);
#
#
#         var popup_68ef4985d4a87c5bce59593b51803f5e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_154d7a206285af8dbe65e75353733e00 = $(`&lt;div id=&quot;html_154d7a206285af8dbe65e75353733e00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Thing: thing name 1&lt;br&gt;Description: thing 1&lt;/div&gt;`)[0];
#                 popup_68ef4985d4a87c5bce59593b51803f5e.setContent(html_154d7a206285af8dbe65e75353733e00);
#
#
#
#         marker_8df92f72c3898fe4ac2ffe9ffd48be1e.bindPopup(popup_68ef4985d4a87c5bce59593b51803f5e)
#         ;
#
#
#
#
#             marker_8df92f72c3898fe4ac2ffe9ffd48be1e.bindTooltip(
#                 `&lt;div&gt;
#                      thing name 1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_23fdf2287ddba703670c0e1e6f20ca91 = L.marker(
#                 [-34.947911309, -130.946808152],
#                 {}
#             ).addTo(map_611771871da37aeb1366f9854d557aed);
#
#
#         var popup_25e1f37aa9ad269b542f5ab8f26c6b3b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eecfa1e706388d5283d7b4fdde4a350b = $(`&lt;div id=&quot;html_eecfa1e706388d5283d7b4fdde4a350b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Thing: thing name 2&lt;br&gt;Description: thing 2&lt;/div&gt;`)[0];
#                 popup_25e1f37aa9ad269b542f5ab8f26c6b3b.setContent(html_eecfa1e706388d5283d7b4fdde4a350b);
#
#
#
#         marker_23fdf2287ddba703670c0e1e6f20ca91.bindPopup(popup_25e1f37aa9ad269b542f5ab8f26c6b3b)
#         ;
#
#
#
#
#             marker_23fdf2287ddba703670c0e1e6f20ca91.bindTooltip(
#                 `&lt;div&gt;
#                      thing name 2
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e70600b1ea2da676abbc6da9ade05510 = L.marker(
#                 [10.074371009, 135.473202101],
#                 {}
#             ).addTo(map_611771871da37aeb1366f9854d557aed);
#
#
#         var popup_7b443d0f83e9fd5f7ee4dd414ac731ad = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8c87ca997aa64bcc5b1d794b49172a60 = $(`&lt;div id=&quot;html_8c87ca997aa64bcc5b1d794b49172a60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Thing: thing name 3&lt;br&gt;Description: thing 3&lt;/div&gt;`)[0];
#                 popup_7b443d0f83e9fd5f7ee4dd414ac731ad.setContent(html_8c87ca997aa64bcc5b1d794b49172a60);
#
#
#
#         marker_e70600b1ea2da676abbc6da9ade05510.bindPopup(popup_7b443d0f83e9fd5f7ee4dd414ac731ad)
#         ;
#
#
#
#
#             marker_e70600b1ea2da676abbc6da9ade05510.bindTooltip(
#                 `&lt;div&gt;
#                      thing name 3
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c83e7a59d89276185fc21b86d15e45d4 = L.marker(
#                 [-43.355386162, 28.920332869],
#                 {}
#             ).addTo(map_611771871da37aeb1366f9854d557aed);
#
#
#         var popup_45cfff41dfa1e2e53996ad307e3b63f8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b8273f83be370949bd1c048fdae24611 = $(`&lt;div id=&quot;html_b8273f83be370949bd1c048fdae24611&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Thing: thing name 4&lt;br&gt;Description: thing 4&lt;/div&gt;`)[0];
#                 popup_45cfff41dfa1e2e53996ad307e3b63f8.setContent(html_b8273f83be370949bd1c048fdae24611);
#
#
#
#         marker_c83e7a59d89276185fc21b86d15e45d4.bindPopup(popup_45cfff41dfa1e2e53996ad307e3b63f8)
#         ;
#
#
#
#
#             marker_c83e7a59d89276185fc21b86d15e45d4.bindTooltip(
#                 `&lt;div&gt;
#                      thing n
