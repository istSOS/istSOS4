# %%
# %load_ext autoreload
# %autoreload 2

# %%
import istsos4_utils as st
from pprint import pprint

# %%
meteo = st.sta('http://api:5000/istsos4/v1.1/')

# %%
Things = meteo.query_api('Things','$expand=Locations')
# Out:
# INFO:root:query_api request: http://api:5000/istsos4/v1.1/Things?$expand=Locations

# %%
map = meteo.map_things(Things)
# Out:
# INFO:root:query_api request: http://api:5000/istsos4/v1.1/Things?$expand=Locations

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f17ef472eef355964f490ebabe24a44d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f17ef472eef355964f490ebabe24a44d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f17ef472eef355964f490ebabe24a44d = L.map(
#                 &quot;map_f17ef472eef355964f490ebabe24a44d&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_98d8e0d74d24b2f435038fd8269cf03a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_98d8e0d74d24b2f435038fd8269cf03a.addTo(map_f17ef472eef355964f490ebabe24a44d);
#
#
#             var marker_78ee20779c6edff2f06daa4fc8ca463e = L.marker(
#                 [48.88763156, 27.800676654],
#                 {}
#             ).addTo(map_f17ef472eef355964f490ebabe24a44d);
#
#
#         var popup_dda819fdc9e858e478119fb28e1c829d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4a64236d2a0360fd158967b0f49da26d = $(`&lt;div id=&quot;html_4a64236d2a0360fd158967b0f49da26d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Thing: thing name 1&lt;br&gt;Description: thing 1&lt;/div&gt;`)[0];
#                 popup_dda819fdc9e858e478119fb28e1c829d.setContent(html_4a64236d2a0360fd158967b0f49da26d);
#
#
#
#         marker_78ee20779c6edff2f06daa4fc8ca463e.bindPopup(popup_dda819fdc9e858e478119fb28e1c829d)
#         ;
#
#
#
#
#             marker_78ee20779c6edff2f06daa4fc8ca463e.bindTooltip(
#                 `&lt;div&gt;
#                      thing name 1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_34a6120ee50d602544b3f2fe33ecedf4 = L.marker(
#                 [-34.947911309, -130.946808152],
#                 {}
#             ).addTo(map_f17ef472eef355964f490ebabe24a44d);
#
#
#         var popup_5a2a87cf8a1c106e489e82ec5d42eb19 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1c6498a90e3baf436eed82966209ba0f = $(`&lt;div id=&quot;html_1c6498a90e3baf436eed82966209ba0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Thing: thing name 2&lt;br&gt;Description: thing 2&lt;/div&gt;`)[0];
#                 popup_5a2a87cf8a1c106e489e82ec5d42eb19.setContent(html_1c6498a90e3baf436eed82966209ba0f);
#
#
#
#         marker_34a6120ee50d602544b3f2fe33ecedf4.bindPopup(popup_5a2a87cf8a1c106e489e82ec5d42eb19)
#         ;
#
#
#
#
#             marker_34a6120ee50d602544b3f2fe33ecedf4.bindTooltip(
#                 `&lt;div&gt;
#                      thing name 2
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f18e565b40ca756c2e37cc945652fcc5 = L.marker(
#                 [10.074371009, 135.473202101],
#                 {}
#             ).addTo(map_f17ef472eef355964f490ebabe24a44d);
#
#
#         var popup_643c6f93394caad8c6682b0c8d3e3e7b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_92355714c70219a8dd721fcf6ebf7337 = $(`&lt;div id=&quot;html_92355714c70219a8dd721fcf6ebf7337&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Thing: thing name 3&lt;br&gt;Description: thing 3&lt;/div&gt;`)[0];
#                 popup_643c6f93394caad8c6682b0c8d3e3e7b.setContent(html_92355714c70219a8dd721fcf6ebf7337);
#
#
#
#         marker_f18e565b40ca756c2e37cc945652fcc5.bindPopup(popup_643c6f93394caad8c6682b0c8d3e3e7b)
#         ;
#
#
#
#
#             marker_f18e565b40ca756c2e37cc945652fcc5.bindTooltip(
#                 `&lt;div&gt;
#                      thing name 3
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_af8cab3435696cc6c7f1c433f201f57a = L.marker(
#                 [-43.355386162, 28.920332869],
#                 {}
#             ).addTo(map_f17ef472eef355964f490ebabe24a44d);
#
#
#         var popup_584795317c2e24f8e1fccb7e85a698c6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6c71a7f46b77811311eb3dba250eb96d = $(`&lt;div id=&quot;html_6c71a7f46b77811311eb3dba250eb96d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Thing: thing name 4&lt;br&gt;Description: thing 4&lt;/div&gt;`)[0];
#                 popup_584795317c2e24f8e1fccb7e85a698c6.setContent(html_6c71a7f46b77811311eb3dba250eb96d);
#
#
#
#         marker_af8cab3435696cc6c7f1c433f201f57a.bindPopup(popup_584795317c2e24f8e1fccb7e85a698c6)
#         ;
#
#
#
#
#             marker_af8cab3435696cc6c7f1c433f201f57a.bindTooltip(
#                 `&lt;div&gt;
#                      thing n
